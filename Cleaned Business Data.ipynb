# %%
# Dependencies
import json
import os
import pandas as pd
import numpy as np

# %%
# read the json
business_json_path = 'Resources/yelp_academic_dataset_business.json'
business_df = pd.read_json(business_json_path, lines=True)

# %%
#Load DataFrame
business_df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2                  5255 E Broadway Blvd         Tucson    AZ       85711
# 3                           935 Race St   Philadelphia    PA       19107
# 4                         101 Walnut St     Green Lane    PA       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    AB     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    TN       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    IN       46250
# 150344                     2472 Troy Rd   Edwardsville    IL       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    FL       33572
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       34.426679 -119.711197    5.0             7        0
# 1       38.551126  -90.335695    3.0            15        1
# 2       32.223236 -110.880452    3.5            22        0
# 3       39.955505  -75.155564    4.0            80        1
# 4       40.338183  -75.471659    4.5            13        1
# ...           ...         ...    ...           ...      ...
# 150341  53.468419 -113.492054    3.0            13        1
# 150342  36.115118  -86.766925    4.0             5        1
# 150343  39.908707  -86.065088    3.5             8        1
# 150344  38.782351  -89.950558    4.0            24        1
# 150345  27.771002  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 1                  {'BusinessAcceptsCreditCards': 'True'}
# 2       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...                                                   ...
# 150341  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344  {'BusinessParking': '{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                    None
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 150343                                               None
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [150346 rows x 14 columns]

# %%
# Columns
business_df.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
# Look at the categories columns
business_df.loc[:,"categories"]
# Out:
# 0         Doctors, Traditional Chinese Medicine, Naturop...
# 1         Shipping Centers, Local Services, Notaries, Ma...
# 2         Department Stores, Shopping, Fashion, Home & G...
# 3         Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                                 Brewpubs, Breweries, Food
#                                 ...
# 150341                           Nail Salons, Beauty & Spas
# 150342    Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343    Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344    Fitness/Exercise Equipment, Eyewear & Optician...
# 150345    Beauty & Spas, Permanent Makeup, Piercing, Tattoo
# Name: categories, Length: 150346, dtype: object

# %%
# Filter categories that contain "Restaurants"
restaurants_df = business_df[business_df['categories'].str.contains('Restaurants', case=False, na=False)]

restaurants_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 150340  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                       address             city state postal_code   latitude  \
# 3                 935 Race St     Philadelphia    PA       19107  39.955505
# 5               615 S Main St     Ashland City    TN       37015  36.269593
# 8           8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9         2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                   Tampa Bay    FL       33602  27.955269
# ...                       ...              ...   ...         ...        ...
# 150325        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339        4405 Pennell Rd            Aston    DE       19014  39.856185
# 150340  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0            80        1
# 5       -87.058943    2.0             6        1
# 8       -90.321087    3.0            19        0
# 9       -86.768170    1.5            10        1
# 11      -82.456320    4.0            10        1
# ...            ...    ...           ...      ...
# 150325  -75.310344    3.0            11        1
# 150327 -116.284689    4.0            33        1
# 150336  -75.158665    4.5            35        1
# 150339  -75.427725    4.5            14        1
# 150340 -113.675999    4.5            18        0
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 8       {'Caters': 'True', 'Alcohol': 'u'full_bar'', '...
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# ...                                                   ...
# 150325  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 150327  {'WiFi': ''free'', 'RestaurantsGoodForGroups':...
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...
# 150339  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 150340  {'Ambience': '{'touristy': False, 'hipster': F...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 8       Pubs, Restaurants, Italian, Bars, American (Tr...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 11             Vietnamese, Food, Restaurants, Food Trucks
# ...                                                   ...
# 150325  Restaurants, Sandwiches, Convenience Stores, C...
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 150336                               Restaurants, Mexican
# 150339  Restaurants, Comfort Food, Food, Food Trucks, ...
# 150340                        Middle Eastern, Restaurants
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 8                                                    None
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# ...                                                   ...
# 150325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150327  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150339  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150340  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [52268 rows x 14 columns]

# %%
#filter for only US data
exclude = ("AB", "XMS")
us_rests_df = restaurants_df[~(restaurants_df["state"].isin(exclude))]
us_rests_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0            80        1
# 5       -87.058943    2.0             6        1
# 8       -90.321087    3.0            19        0
# 9       -86.768170    1.5            10        1
# 11      -82.456320    4.0            10        1
# ...            ...    ...           ...      ...
# 150323 -116.202383    4.5           998        1
# 150325  -75.310344    3.0            11        1
# 150327 -116.284689    4.0            33        1
# 150336  -75.158665    4.5            35        1
# 150339  -75.427725    4.5            14        1
#
#                                                attributes  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 8       {'Caters': 'True', 'Alcohol': 'u'full_bar'', '...
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# ...                                                   ...
# 150323  {'BikeParking': 'True', 'Alcohol': 'u'full_bar...
# 150325  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 150327  {'WiFi': ''free'', 'RestaurantsGoodForGroups':...
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...
# 150339  {'RestaurantsDelivery': 'False', 'BusinessAcce...
#
#                                                categories  \
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 8       Pubs, Restaurants, Italian, Bars, American (Tr...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 11             Vietnamese, Food, Restaurants, Food Trucks
# ...                                                   ...
# 150323  Bars, Gastropubs, Sandwiches, Nightlife, Resta...
# 150325  Restaurants, Sandwiches, Convenience Stores, C...
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
# 150336                               Restaurants, Mexican
# 150339  Restaurants, Comfort Food, Food, Food Trucks, ...
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 8                                                    None
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# ...                                                   ...
# 150323  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...
# 150325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150327  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150339  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
#
# [49857 rows x 14 columns]

# %%
#Extract the attributes to it's own column.
attributes_df = pd.concat([us_rests_df, us_rests_df["attributes"].apply(pd.Series)], axis=1)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  ...  \
# 3       -75.155564    4.0            80  ...
# 5       -87.058943    2.0             6  ...
# 8       -90.321087    3.0            19  ...
# 9       -86.768170    1.5            10  ...
# 11      -82.456320    4.0            10  ...
# ...            ...    ...           ...  ...
# 150323 -116.202383    4.5           998  ...
# 150325  -75.310344    3.0            11  ...
# 150327 -116.284689    4.0            33  ...
# 150336  -75.158665    4.5            35  ...
# 150339  -75.427725    4.5            14  ...
#
#                                                BestNights BYOB Corkage  \
# 3                                                     NaN  NaN     NaN
# 5                                                     NaN  NaN     NaN
# 8                                                     NaN  NaN     NaN
# 9                                                     NaN  NaN     NaN
# 11                                                    NaN  NaN     NaN
# ...                                                   ...  ...     ...
# 150323  {'monday': False, 'tuesday': False, 'friday': ...  NaN     NaN
# 150325                                                NaN  NaN     NaN
# 150327                                                NaN  NaN     NaN
# 150336                                                NaN  NaN     NaN
# 150339                                                NaN  NaN     NaN
#
#        BYOBCorkage RestaurantsCounterService Open24Hours AgesAllowed  \
# 3              NaN                       NaN         NaN         NaN
# 5              NaN                       NaN         NaN         NaN
# 8              NaN                       NaN         NaN         NaN
# 9              NaN                       NaN         NaN         NaN
# 11             NaN                       NaN         NaN         NaN
# ...            ...                       ...         ...         ...
# 150323        'no'                       NaN         NaN         NaN
# 150325         NaN                       NaN         NaN         NaN
# 150327         NaN                       NaN         NaN         NaN
# 150336         NaN                       NaN         NaN         NaN
# 150339         NaN                       NaN         NaN         NaN
#
#        DietaryRestrictions AcceptsInsurance HairSpecializesIn
# 3                      NaN              NaN               NaN
# 5                      NaN              NaN               NaN
# 8                      NaN              NaN               NaN
# 9                      NaN              NaN               NaN
# 11                     NaN              NaN               NaN
# ...                    ...              ...               ...
# 150323                 NaN              NaN               NaN
# 150325                 NaN              NaN               NaN
# 150327                 NaN              NaN               NaN
# 150336                 NaN              NaN               NaN
# 150339                 NaN              NaN               NaN
#
# [49857 rows x 53 columns]

# %%
# create new dataframe with only columns relevant for our analysis 
attributes_df = attributes_df[['business_id', 'name', 'address', 'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars', 'review_count', 'RestaurantsDelivery',
                               'OutdoorSeating', 'RestaurantsTakeOut', 'WiFi', 'RestaurantsReservations', 'RestaurantsGoodForGroups', 'WheelchairAccessible', 'HappyHour', 'DietaryRestrictions']]

# %%
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count RestaurantsDelivery OutdoorSeating  \
# 3       -75.155564    4.0            80               False          False
# 5       -87.058943    2.0             6                True           True
# 8       -90.321087    3.0            19               False           True
# 9       -86.768170    1.5            10                True           True
# 11      -82.456320    4.0            10                 NaN           None
# ...            ...    ...           ...                 ...            ...
# 150323 -116.202383    4.5           998                None           None
# 150325  -75.310344    3.0            11                True            NaN
# 150327 -116.284689    4.0            33               False           True
# 150336  -75.158665    4.5            35                True          False
# 150339  -75.427725    4.5            14               False            NaN
#
#        RestaurantsTakeOut     WiFi RestaurantsReservations  \
# 3                    True  u'free'                     NaN
# 5                    True    u'no'                   False
# 8                    True  u'free'                   False
# 9                    True    u'no'                   False
# 11                    NaN      NaN                   False
# ...                   ...      ...                     ...
# 150323               None  u'free'                   False
# 150325               True      NaN                     NaN
# 150327              False   'free'                   False
# 150336               True  u'free'                   False
# 150339               True      NaN                     NaN
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                           NaN                  NaN       NaN
# 5                          True                 True     False
# 8                          True                  NaN       NaN
# 9                         False                 True     False
# 11                          NaN                  NaN       NaN
# ...                         ...                  ...       ...
# 150323                     True                  NaN       NaN
# 150325                      NaN                  NaN       NaN
# 150327                     True                  NaN       NaN
# 150336                     True                False     False
# 150339                      NaN                 True       NaN
#
#        DietaryRestrictions
# 3                      NaN
# 5                      NaN
# 8                      NaN
# 9                      NaN
# 11                     NaN
# ...                    ...
# 150323                 NaN
# 150325                 NaN
# 150327                 NaN
# 150336                 NaN
# 150339                 NaN
#
# [49857 rows x 19 columns]

# %%
attributes_df.dtypes
# Out:
# business_id                  object
# name                         object
# address                      object
# city                         object
# state                        object
# postal_code                  object
# latitude                    float64
# longitude                   float64
# stars                       float64
# review_count                  int64
# RestaurantsDelivery          object
# OutdoorSeating               object
# RestaurantsTakeOut           object
# WiFi                         object
# RestaurantsReservations      object
# RestaurantsGoodForGroups     object
# WheelchairAccessible         object
# HappyHour                    object
# DietaryRestrictions          object
# dtype: object

# %%
attributes_df['DietaryRestrictions'] = attributes_df['DietaryRestrictions'].replace(np.nan, 0)
def changeStatus(status):
    if status == 0:
        return 0
    else:
        return 1
attributes_df['DietaryRestrictions'] = attributes_df['DietaryRestrictions'].apply(changeStatus)
attributes_df
# Out:
# C:\Users\nchau\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\nchau\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count RestaurantsDelivery OutdoorSeating  \
# 3       -75.155564    4.0            80               False          False
# 5       -87.058943    2.0             6                True           True
# 8       -90.321087    3.0            19               False           True
# 9       -86.768170    1.5            10                True           True
# 11      -82.456320    4.0            10                 NaN           None
# ...            ...    ...           ...                 ...            ...
# 150323 -116.202383    4.5           998                None           None
# 150325  -75.310344    3.0            11                True            NaN
# 150327 -116.284689    4.0            33               False           True
# 150336  -75.158665    4.5            35                True          False
# 150339  -75.427725    4.5            14               False            NaN
#
#        RestaurantsTakeOut     WiFi RestaurantsReservations  \
# 3                    True  u'free'                     NaN
# 5                    True    u'no'                   False
# 8                    True  u'free'                   False
# 9                    True    u'no'                   False
# 11                    NaN      NaN                   False
# ...                   ...      ...                     ...
# 150323               None  u'free'                   False
# 150325               True      NaN                     NaN
# 150327              False   'free'                   False
# 150336               True  u'free'                   False
# 150339               True      NaN                     NaN
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                           NaN                  NaN       NaN
# 5                          True                 True     False
# 8                          True                  NaN       NaN
# 9                         False                 True     False
# 11                          NaN                  NaN       NaN
# ...                         ...                  ...       ...
# 150323                     True                  NaN       NaN
# 150325                      NaN                  NaN       NaN
# 150327                     True                  NaN       NaN
# 150336                     True                False     False
# 150339                      NaN                 True       NaN
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
attributes_df['WiFi'] = attributes_df['WiFi'].replace(np.nan, 0)
def changeStatus(status):
    if status == 0:
        return 0
    elif status == "u'no'":
        return 0
    else:
        return 1
attributes_df['WiFi'] = attributes_df['WiFi'].apply(changeStatus)
attributes_df
# Out:
# C:\Users\nchau\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\nchau\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count RestaurantsDelivery OutdoorSeating  \
# 3       -75.155564    4.0            80               False          False
# 5       -87.058943    2.0             6                True           True
# 8       -90.321087    3.0            19               False           True
# 9       -86.768170    1.5            10                True           True
# 11      -82.456320    4.0            10                 NaN           None
# ...            ...    ...           ...                 ...            ...
# 150323 -116.202383    4.5           998                None           None
# 150325  -75.310344    3.0            11                True            NaN
# 150327 -116.284689    4.0            33               False           True
# 150336  -75.158665    4.5            35                True          False
# 150339  -75.427725    4.5            14               False            NaN
#
#        RestaurantsTakeOut  WiFi RestaurantsReservations  \
# 3                    True     1                     NaN
# 5                    True     0                   False
# 8                    True     1                   False
# 9                    True     0                   False
# 11                    NaN     0                   False
# ...                   ...   ...                     ...
# 150323               None     1                   False
# 150325               True     0                     NaN
# 150327              False     1                   False
# 150336               True     1                   False
# 150339               True     0                     NaN
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                           NaN                  NaN       NaN
# 5                          True                 True     False
# 8                          True                  NaN       NaN
# 9                         False                 True     False
# 11                          NaN                  NaN       NaN
# ...                         ...                  ...       ...
# 150323                     True                  NaN       NaN
# 150325                      NaN                  NaN       NaN
# 150327                     True                  NaN       NaN
# 150336                     True                False     False
# 150339                      NaN                 True       NaN
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
attributes_df=attributes_df.fillna(0)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count RestaurantsDelivery OutdoorSeating  \
# 3       -75.155564    4.0            80               False          False
# 5       -87.058943    2.0             6                True           True
# 8       -90.321087    3.0            19               False           True
# 9       -86.768170    1.5            10                True           True
# 11      -82.456320    4.0            10                   0           None
# ...            ...    ...           ...                 ...            ...
# 150323 -116.202383    4.5           998                None           None
# 150325  -75.310344    3.0            11                True              0
# 150327 -116.284689    4.0            33               False           True
# 150336  -75.158665    4.5            35                True          False
# 150339  -75.427725    4.5            14               False              0
#
#        RestaurantsTakeOut  WiFi RestaurantsReservations  \
# 3                    True     1                       0
# 5                    True     0                   False
# 8                    True     1                   False
# 9                    True     0                   False
# 11                      0     0                   False
# ...                   ...   ...                     ...
# 150323               None     1                   False
# 150325               True     0                       0
# 150327              False     1                   False
# 150336               True     1                   False
# 150339               True     0                       0
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                             0                    0         0
# 5                          True                 True     False
# 8                          True                    0         0
# 9                         False                 True     False
# 11                            0                    0         0
# ...                         ...                  ...       ...
# 150323                     True                    0         0
# 150325                        0                    0         0
# 150327                     True                    0         0
# 150336                     True                False     False
# 150339                        0                 True         0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Replacing 'RestaurantsDelivery' True and false with 1 and 0
def changeStatus(status):
    if status == 0:
        return 0
    elif status == 'False':
        return 0
    else:
        return 1
attributes_df['RestaurantsDelivery'] = attributes_df['RestaurantsDelivery'].apply(changeStatus)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  RestaurantsDelivery OutdoorSeating  \
# 3       -75.155564    4.0            80                    0          False
# 5       -87.058943    2.0             6                    1           True
# 8       -90.321087    3.0            19                    0           True
# 9       -86.768170    1.5            10                    1           True
# 11      -82.456320    4.0            10                    0           None
# ...            ...    ...           ...                  ...            ...
# 150323 -116.202383    4.5           998                    1           None
# 150325  -75.310344    3.0            11                    1              0
# 150327 -116.284689    4.0            33                    0           True
# 150336  -75.158665    4.5            35                    1          False
# 150339  -75.427725    4.5            14                    0              0
#
#        RestaurantsTakeOut  WiFi RestaurantsReservations  \
# 3                    True     1                       0
# 5                    True     0                   False
# 8                    True     1                   False
# 9                    True     0                   False
# 11                      0     0                   False
# ...                   ...   ...                     ...
# 150323               None     1                   False
# 150325               True     0                       0
# 150327              False     1                   False
# 150336               True     1                   False
# 150339               True     0                       0
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                             0                    0         0
# 5                          True                 True     False
# 8                          True                    0         0
# 9                         False                 True     False
# 11                            0                    0         0
# ...                         ...                  ...       ...
# 150323                     True                    0         0
# 150325                        0                    0         0
# 150327                     True                    0         0
# 150336                     True                False     False
# 150339                        0                 True         0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Replacing 'OutdoorSeating' True and false with 1 and 0
def changeStatus(status):
    if status == 0:
        return 0
    elif status == 'False':
        return 0
    else:
        return 1
attributes_df['OutdoorSeating'] = attributes_df['OutdoorSeating'].apply(changeStatus)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  RestaurantsDelivery  OutdoorSeating  \
# 3       -75.155564    4.0            80                    0               0
# 5       -87.058943    2.0             6                    1               1
# 8       -90.321087    3.0            19                    0               1
# 9       -86.768170    1.5            10                    1               1
# 11      -82.456320    4.0            10                    0               1
# ...            ...    ...           ...                  ...             ...
# 150323 -116.202383    4.5           998                    1               1
# 150325  -75.310344    3.0            11                    1               0
# 150327 -116.284689    4.0            33                    0               1
# 150336  -75.158665    4.5            35                    1               0
# 150339  -75.427725    4.5            14                    0               0
#
#        RestaurantsTakeOut  WiFi RestaurantsReservations  \
# 3                    True     1                       0
# 5                    True     0                   False
# 8                    True     1                   False
# 9                    True     0                   False
# 11                      0     0                   False
# ...                   ...   ...                     ...
# 150323               None     1                   False
# 150325               True     0                       0
# 150327              False     1                   False
# 150336               True     1                   False
# 150339               True     0                       0
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                             0                    0         0
# 5                          True                 True     False
# 8                          True                    0         0
# 9                         False                 True     False
# 11                            0                    0         0
# ...                         ...                  ...       ...
# 150323                     True                    0         0
# 150325                        0                    0         0
# 150327                     True                    0         0
# 150336                     True                False     False
# 150339                        0                 True         0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Replacing 'RestaurantsTakeOut' True and false with 1 and 0
def changeStatus(status):
    if status == 0:
        return 0
    elif status == 'False':
        return 0
    else:
        return 1
attributes_df['RestaurantsTakeOut'] = attributes_df['RestaurantsTakeOut'].apply(changeStatus)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  RestaurantsDelivery  OutdoorSeating  \
# 3       -75.155564    4.0            80                    0               0
# 5       -87.058943    2.0             6                    1               1
# 8       -90.321087    3.0            19                    0               1
# 9       -86.768170    1.5            10                    1               1
# 11      -82.456320    4.0            10                    0               1
# ...            ...    ...           ...                  ...             ...
# 150323 -116.202383    4.5           998                    1               1
# 150325  -75.310344    3.0            11                    1               0
# 150327 -116.284689    4.0            33                    0               1
# 150336  -75.158665    4.5            35                    1               0
# 150339  -75.427725    4.5            14                    0               0
#
#         RestaurantsTakeOut  WiFi RestaurantsReservations  \
# 3                        1     1                       0
# 5                        1     0                   False
# 8                        1     1                   False
# 9                        1     0                   False
# 11                       0     0                   False
# ...                    ...   ...                     ...
# 150323                   1     1                   False
# 150325                   1     0                       0
# 150327                   0     1                   False
# 150336                   1     1                   False
# 150339                   1     0                       0
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                             0                    0         0
# 5                          True                 True     False
# 8                          True                    0         0
# 9                         False                 True     False
# 11                            0                    0         0
# ...                         ...                  ...       ...
# 150323                     True                    0         0
# 150325                        0                    0         0
# 150327                     True                    0         0
# 150336                     True                False     False
# 150339                        0                 True         0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Replacing 'RestaurantsReservations' True and false with 1 and 0
def changeStatus(status):
    if status == 0:
        return 0
    elif status == 'False':
        return 0
    else:
        return 1
attributes_df['RestaurantsReservations'] = attributes_df['RestaurantsReservations'].apply(changeStatus)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  RestaurantsDelivery  OutdoorSeating  \
# 3       -75.155564    4.0            80                    0               0
# 5       -87.058943    2.0             6                    1               1
# 8       -90.321087    3.0            19                    0               1
# 9       -86.768170    1.5            10                    1               1
# 11      -82.456320    4.0            10                    0               1
# ...            ...    ...           ...                  ...             ...
# 150323 -116.202383    4.5           998                    1               1
# 150325  -75.310344    3.0            11                    1               0
# 150327 -116.284689    4.0            33                    0               1
# 150336  -75.158665    4.5            35                    1               0
# 150339  -75.427725    4.5            14                    0               0
#
#         RestaurantsTakeOut  WiFi  RestaurantsReservations  \
# 3                        1     1                        0
# 5                        1     0                        0
# 8                        1     1                        0
# 9                        1     0                        0
# 11                       0     0                        0
# ...                    ...   ...                      ...
# 150323                   1     1                        0
# 150325                   1     0                        0
# 150327                   0     1                        0
# 150336                   1     1                        0
# 150339                   1     0                        0
#
#        RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                             0                    0         0
# 5                          True                 True     False
# 8                          True                    0         0
# 9                         False                 True     False
# 11                            0                    0         0
# ...                         ...                  ...       ...
# 150323                     True                    0         0
# 150325                        0                    0         0
# 150327                     True                    0         0
# 150336                     True                False     False
# 150339                        0                 True         0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Replacing 'RestaurantsGoodForGroups' True and false with 1 and 0
def changeStatus(status):
    if status == 0:
        return 0
    elif status == 'False':
        return 0
    else:
        return 1
attributes_df['RestaurantsGoodForGroups'] = attributes_df['RestaurantsGoodForGroups'].apply(changeStatus)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  RestaurantsDelivery  OutdoorSeating  \
# 3       -75.155564    4.0            80                    0               0
# 5       -87.058943    2.0             6                    1               1
# 8       -90.321087    3.0            19                    0               1
# 9       -86.768170    1.5            10                    1               1
# 11      -82.456320    4.0            10                    0               1
# ...            ...    ...           ...                  ...             ...
# 150323 -116.202383    4.5           998                    1               1
# 150325  -75.310344    3.0            11                    1               0
# 150327 -116.284689    4.0            33                    0               1
# 150336  -75.158665    4.5            35                    1               0
# 150339  -75.427725    4.5            14                    0               0
#
#         RestaurantsTakeOut  WiFi  RestaurantsReservations  \
# 3                        1     1                        0
# 5                        1     0                        0
# 8                        1     1                        0
# 9                        1     0                        0
# 11                       0     0                        0
# ...                    ...   ...                      ...
# 150323                   1     1                        0
# 150325                   1     0                        0
# 150327                   0     1                        0
# 150336                   1     1                        0
# 150339                   1     0                        0
#
#         RestaurantsGoodForGroups WheelchairAccessible HappyHour  \
# 3                              0                    0         0
# 5                              1                 True     False
# 8                              1                    0         0
# 9                              0                 True     False
# 11                             0                    0         0
# ...                          ...                  ...       ...
# 150323                         1                    0         0
# 150325                         0                    0         0
# 150327                         1                    0         0
# 150336                         1                False     False
# 150339                         0                 True         0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Replacing 'WheelchairAccessible' True and false with 1 and 0
def changeStatus(status):
    if status == 0:
        return 0
    elif status == 'False':
        return 0
    else:
        return 1
attributes_df['WheelchairAccessible'] = attributes_df['WheelchairAccessible'].apply(changeStatus)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  RestaurantsDelivery  OutdoorSeating  \
# 3       -75.155564    4.0            80                    0               0
# 5       -87.058943    2.0             6                    1               1
# 8       -90.321087    3.0            19                    0               1
# 9       -86.768170    1.5            10                    1               1
# 11      -82.456320    4.0            10                    0               1
# ...            ...    ...           ...                  ...             ...
# 150323 -116.202383    4.5           998                    1               1
# 150325  -75.310344    3.0            11                    1               0
# 150327 -116.284689    4.0            33                    0               1
# 150336  -75.158665    4.5            35                    1               0
# 150339  -75.427725    4.5            14                    0               0
#
#         RestaurantsTakeOut  WiFi  RestaurantsReservations  \
# 3                        1     1                        0
# 5                        1     0                        0
# 8                        1     1                        0
# 9                        1     0                        0
# 11                       0     0                        0
# ...                    ...   ...                      ...
# 150323                   1     1                        0
# 150325                   1     0                        0
# 150327                   0     1                        0
# 150336                   1     1                        0
# 150339                   1     0                        0
#
#         RestaurantsGoodForGroups  WheelchairAccessible HappyHour  \
# 3                              0                     0         0
# 5                              1                     1     False
# 8                              1                     0         0
# 9                              0                     1     False
# 11                             0                     0         0
# ...                          ...                   ...       ...
# 150323                         1                     0         0
# 150325                         0                     0         0
# 150327                         1                     0         0
# 150336                         1                     0     False
# 150339                         0                     1         0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Replacing 'HappyHour' True and false with 1 and 0
def changeStatus(status):
    if status == 0:
        return 0
    elif status == 'False':
        return 0
    else:
        return 1
attributes_df['HappyHour'] = attributes_df['HappyHour'].apply(changeStatus)
attributes_df
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 8       k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                        ...                            ...
# 150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
#
#                     address             city state postal_code   latitude  \
# 3               935 Race St     Philadelphia    PA       19107  39.955505
# 5             615 S Main St     Ashland City    TN       37015  36.269593
# 8         8025 Mackenzie Rd           Affton    MO       63123  38.565165
# 9       2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                 Tampa Bay    FL       33602  27.955269
# ...                     ...              ...   ...         ...        ...
# 150323         246 N 8th St            Boise    ID       83702  43.616590
# 150325      19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327  1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336        1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339      4405 Pennell Rd            Aston    DE       19014  39.856185
#
#          longitude  stars  review_count  RestaurantsDelivery  OutdoorSeating  \
# 3       -75.155564    4.0            80                    0               0
# 5       -87.058943    2.0             6                    1               1
# 8       -90.321087    3.0            19                    0               1
# 9       -86.768170    1.5            10                    1               1
# 11      -82.456320    4.0            10                    0               1
# ...            ...    ...           ...                  ...             ...
# 150323 -116.202383    4.5           998                    1               1
# 150325  -75.310344    3.0            11                    1               0
# 150327 -116.284689    4.0            33                    0               1
# 150336  -75.158665    4.5            35                    1               0
# 150339  -75.427725    4.5            14                    0               0
#
#         RestaurantsTakeOut  WiFi  RestaurantsReservations  \
# 3                        1     1                        0
# 5                        1     0                        0
# 8                        1     1                        0
# 9                        1     0                        0
# 11                       0     0                        0
# ...                    ...   ...                      ...
# 150323                   1     1                        0
# 150325                   1     0                        0
# 150327                   0     1                        0
# 150336                   1     1                        0
# 150339                   1     0                        0
#
#         RestaurantsGoodForGroups  WheelchairAccessible  HappyHour  \
# 3                              0                     0          0
# 5                              1                     1          0
# 8                              1                     0          0
# 9                              0                     1          0
# 11                             0                     0          0
# ...                          ...                   ...        ...
# 150323                         1                     0          0
# 150325                         0                     0          0
# 150327                         1                     0          0
# 150336                         1                     0          0
# 150339                         0                     1          0
#
#         DietaryRestrictions
# 3                         0
# 5                         0
# 8                         0
# 9                         0
# 11                        0
# ...                     ...
# 150323                    0
# 150325                    0
# 150327                    0
# 150336                    0
# 150339                    0
#
# [49857 rows x 19 columns]

# %%
# Using .rename(columns={}) in order to rename columnsattributes_df
renamed_df = attributes_df.rename(columns={"business_id":"Restaurant_ID", "name":"Restaurants_Name", "address":"Address","city":"City",
                                          "state":"State","postal_code":"Postal_Code","latitude":"Latitude","longitude":"Longitude","stars":"Stars",
                                           "review_count":"Review_Count","RestaurantsDelivery":"Restaurants_Delivery","OutdoorSeating":"Outdoor_Seating","RestaurantsTakeOut":"Restaurants_TakeOut",
                                           "WiFi":"WiFi", "RestaurantsReservations":"Restaurants_Reservations","RestaurantsGoodForGroups":"Good_For_Groups", "WheelchairAccessible":"Wheelchair_Accessible", "HappyHour":"Happy_Hour", "DietaryRestrictions":"Dietary_Restrictions"})
renamed_df.head()
# Out:
#              Restaurant_ID       Restaurants_Name              Address  \
# 3   MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries          935 Race St
# 5   CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In        615 S Main St
# 8   k0hlBqXX-Bt0vf1op7Jr1w  Tsevi's Pub And Grill    8025 Mackenzie Rd
# 9   bBDDEgkFA1Otx9Lfe7BZUQ         Sonic Drive-In  2312 Dickerson Pike
# 11  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck
#
#             City State Postal_Code   Latitude  Longitude  Stars  Review_Count  \
# 3   Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 5   Ashland City    TN       37015  36.269593 -87.058943    2.0             6
# 8         Affton    MO       63123  38.565165 -90.321087    3.0            19
# 9      Nashville    TN       37207  36.208102 -86.768170    1.5            10
# 11     Tampa Bay    FL       33602  27.955269 -82.456320    4.0            10
#
#     Restaurants_Delivery  Outdoor_Seating  Restaurants_TakeOut  WiFi  \
# 3                      0                0                    1     1
# 5                      1                1                    1     0
# 8                      0                1                    1     1
# 9                      1                1                    1     0
# 11                     0                1                    0     0
#
#     Restaurants_Reservations  Good_For_Groups  Wheelchair_Accessible  \
# 3                          0                0                      0
# 5                          0                1                      1
# 8                          0                1                      0
# 9                          0                0                      1
# 11                         0                0                      0
#
#     Happy_Hour  Dietary_Restrictions
# 3            0                     0
# 5            0                     0
# 8            0                     0
# 9            0                     0
# 11           0                     0

# %%
renamed_df.to_csv(r'C:\Users\nchau\Yelp-Project\Clean_Data.csv')

# %%
renamed_df.count()
# Out:
# Restaurant_ID               49857
# Restaurants_Name            49857
# Address                     49857
# City                        49857
# State                       49857
# Postal_Code                 49857
# Latitude                    49857
# Longitude                   49857
# Stars                       49857
# Review_Count                49857
# Restaurants_Delivery        49857
# Outdoor_Seating             49857
# Restaurants_TakeOut         49857
# WiFi                        49857
# Restaurants_Reservations    49857
# Good_For_Groups             49857
# Wheelchair_Accessible       49857
# Happy_Hour                  49857
# Dietary_Restrictions        49857
# dtype: int64
