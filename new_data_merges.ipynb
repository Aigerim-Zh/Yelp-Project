# %%
import pandas as pd
import numpy as np

# %%
business_df = pd.read_csv('CSV_files/Business.csv')

# %%
business_df.head()
# Out:
#             Restaurant_ID         Restaurants_Name             Address  \
# 0  MTSW4McQd7CbVtyjqoe9mw       St Honore Pastries         935 Race St
# 1  0bPLkL0QhhPO5kt1_EXmNQ     Zio's Italian Market       2575 E Bay Dr
# 2  MUTTqe8uqyMdBl186RmNeA                 Tuna Bar         205 Race St
# 3  ROeacJQwBeh05Rqg7F6TCg                      BAP       1224 South St
# 4  9OG5YkX1g2GReZM0AskizA  Romano's Macaroni Grill  5505 S Virginia St
#
#            City State  Postal_Code   Latitude   Longitude  Stars_Rating  \
# 0  Philadelphia    PA        19107  39.955505  -75.155564           4.0
# 1         Largo    FL        33771  27.916116  -82.760461           4.5
# 2  Philadelphia    PA        19106  39.953949  -75.143226           4.0
# 3  Philadelphia    PA        19147  39.943223  -75.162568           4.5
# 4          Reno    NV        89502  39.476117 -119.789339           2.5
#
#    Review_Count  ...  Alcohol  Good_For_Kids  Reservations  \
# ...

# %%
# business_df.dtypes

# %%
business_df.count()
# Out:
# Restaurant_ID            27205
# Restaurants_Name         27205
# Address                  27136
# City                     27205
# State                    27205
# Postal_Code              27205
# Latitude                 27205
# Longitude                27205
# Stars_Rating             27205
# Review_Count             27205
# Restaurants_Delivery     27205
# Outdoor_Seating          27205
# Accepts_CreditCards      27205
# Price_Range              27205
# Alcohol                  27205
# Good_For_Kids            27205
# Reservations             27205
# Restaurants_TakeOut      27205
# WiFi                     27205
# Good_For_Groups          27205
# Wheelchair_Accessible    27205
# Happy_Hour               27205
# Noise_Level              27205
# Dietary_Restrictions     27205
# dtype: int64

# %%
census_df = pd.read_csv('CSV_files/Census_income.csv')

# %%
census_df.head()
# Out:
#    Postal_Code  Total_Estimate_Households_per_Zip  \
# 0        84531                                187
# 1        84536                                376
# 2        85003                               4378
# 3        85004                               3584
# 4        85006                               9471
#
#    Total_Estimate_Married-couple_Family_households  \
# 0                                               58
# 1                                              110
# 2                                              942
# 3                                              611
# 4                                             2635
#
#    Total_Estimate_Nonfamily_households  Median_Income(dollars)  \
# 0                                   42                   25972
# 1                                  160                   20385
# 2                                 2928                   48306
# 3                                 2831                   52000
# ...

# %%
census_df.count()
# Out:
# Postal_Code                                        9045
# Total_Estimate_Households_per_Zip                  9045
# Total_Estimate_Married-couple_Family_households    9045
# Total_Estimate_Nonfamily_households                9045
# Median_Income(dollars)                             9045
# Mean_Income(dollars)                               9045
# dtype: int64

# %%
# census_df.dtypes

# %%
census_df.dropna(axis=0, inplace=True)

# %%
census_df.count()
# Out:
# Postal_Code                                        9045
# Total_Estimate_Households_per_Zip                  9045
# Total_Estimate_Married-couple_Family_households    9045
# Total_Estimate_Nonfamily_households                9045
# Median_Income(dollars)                             9045
# Mean_Income(dollars)                               9045
# dtype: int64

# %%
merged_df = pd.merge(business_df, census_df, left_on='Postal_Code', right_on='Postal_Code', how='inner')

# %%
merged_df.count()
# Out:
# Restaurant_ID                                      24739
# Restaurants_Name                                   24739
# Address                                            24681
# City                                               24739
# State                                              24739
# Postal_Code                                        24739
# Latitude                                           24739
# Longitude                                          24739
# Stars_Rating                                       24739
# Review_Count                                       24739
# Restaurants_Delivery                               24739
# Outdoor_Seating                                    24739
# Accepts_CreditCards                                24739
# Price_Range                                        24739
# Alcohol                                            24739
# Good_For_Kids                                      24739
# ...

# %%
merged_df.head()
# Out:
#             Restaurant_ID    Restaurants_Name         Address          City  \
# 0  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries     935 Race St  Philadelphia
# 1  WYYdQDjx-DsCanlP0DpImQ             J Sushi   243 S 10th St  Philadelphia
# 2  ngvE1G9IckUO-ljZBFo23w       Mumbai Bistro   930 Locust St  Philadelphia
# 3  IgNDlyLERBwFGphgcC5VDQ                Cosi  1128 Walnut St  Philadelphia
# 4  L_sXNadtVHjxMw7Yhvkj9Q         Naoki Ramen     915 Race St  Philadelphia
#
#   State  Postal_Code   Latitude  Longitude  Stars_Rating  Review_Count  ...  \
# 0    PA        19107  39.955505 -75.155564           4.0            80  ...
# 1    PA        19107  39.947033 -75.157434           4.5            72  ...
# 2    PA        19107  39.947207 -75.157252           4.0           217  ...
# 3    PA        19107  39.948751 -75.160449           2.5            63  ...
# 4    PA        19107  39.955454 -75.154900           4.0            92  ...
#
# ...

# %%
merged_df.tail()
# Out:
#                 Restaurant_ID                     Restaurants_Name  \
# 24734  IFUgn1pFknZQ9OpN9EmyYw        Hudock's Frozen Custard Stand
# 24735  tZy556-b1uO9pcy0WsumIA      Charlie's Restaurant & Catering
# 24736  jMStvE-tQzSpRCAO0nAE6g  Red Robin Gourmet Burgers and Brews
# 24737  r4oV3EWnJX-1hjhNcKMI7w                   Ortino's Northside
# 24738  NagkUmgLHFd1s8RTk1tcKw                       Old Father Inn
#
#                         Address            City State  Postal_Code   Latitude  \
# 24734      544 Salem Quinton Rd           Salem    NJ         8079  39.560427
# 24735  6129 E Saint Bernard Hwy          Violet    LA        70092  29.900428
# 24736        4605 S Landing Way          Tucson    AZ        32246  32.167311
# 24737          1355 Gravel Pike  Perkiomenville    PA        18074  40.291583
# 24738             4080 W Ina Rd          Marana    AZ        85653  32.338120
#
#         Longitude  Stars_Rating  Review_Count  ...  Good_For_Groups  \
# ...

# %%
merged_df.dtypes
# Out:
# Restaurant_ID                                       object
# Restaurants_Name                                    object
# Address                                             object
# City                                                object
# State                                               object
# Postal_Code                                          int64
# Latitude                                           float64
# Longitude                                          float64
# Stars_Rating                                       float64
# Review_Count                                         int64
# Restaurants_Delivery                                 int64
# Outdoor_Seating                                      int64
# Accepts_CreditCards                                  int64
# Price_Range                                          int64
# Alcohol                                              int64
# Good_For_Kids                                        int64
# ...

# %%
merged_df.columns
# Out:
# Index(['Restaurant_ID', 'Restaurants_Name', 'Address', 'City', 'State',
#        'Postal_Code', 'Latitude', 'Longitude', 'Stars_Rating', 'Review_Count',
#        'Restaurants_Delivery', 'Outdoor_Seating', 'Accepts_CreditCards',
#        'Price_Range', 'Alcohol', 'Good_For_Kids', 'Reservations',
#        'Restaurants_TakeOut', 'WiFi', 'Good_For_Groups',
#        'Wheelchair_Accessible', 'Happy_Hour', 'Noise_Level',
#        'Dietary_Restrictions', 'Total_Estimate_Households_per_Zip',
#        'Total_Estimate_Married-couple_Family_households',
#        'Total_Estimate_Nonfamily_households', 'Median_Income(dollars)',
#        'Mean_Income(dollars)'],
#       dtype='object')

# %%
merged_df.dropna(subset=['Total_Estimate_Households_per_Zip',
       'Total_Estimate_Married-couple_Family_households',
       'Total_Estimate_Nonfamily_households', 'Median_Income(dollars)',
       'Mean_Income(dollars)'
       ], axis=0, inplace=True)

# %%
merged_df.count()
# Out:
# Restaurant_ID                                      24739
# Restaurants_Name                                   24739
# Address                                            24681
# City                                               24739
# State                                              24739
# Postal_Code                                        24739
# Latitude                                           24739
# Longitude                                          24739
# Stars_Rating                                       24739
# Review_Count                                       24739
# Restaurants_Delivery                               24739
# Outdoor_Seating                                    24739
# Accepts_CreditCards                                24739
# Price_Range                                        24739
# Alcohol                                            24739
# Good_For_Kids                                      24739
# ...

# %%
merged_df.dtypes
# Out:
# Restaurant_ID                                       object
# Restaurants_Name                                    object
# Address                                             object
# City                                                object
# State                                               object
# Postal_Code                                          int64
# Latitude                                           float64
# Longitude                                          float64
# Stars_Rating                                       float64
# Review_Count                                         int64
# Restaurants_Delivery                                 int64
# Outdoor_Seating                                      int64
# Accepts_CreditCards                                  int64
# Price_Range                                          int64
# Alcohol                                              int64
# Good_For_Kids                                        int64
# ...

# %%
merged_df.head()
# Out:
#             Restaurant_ID    Restaurants_Name         Address          City  \
# 0  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries     935 Race St  Philadelphia
# 1  WYYdQDjx-DsCanlP0DpImQ             J Sushi   243 S 10th St  Philadelphia
# 2  ngvE1G9IckUO-ljZBFo23w       Mumbai Bistro   930 Locust St  Philadelphia
# 3  IgNDlyLERBwFGphgcC5VDQ                Cosi  1128 Walnut St  Philadelphia
# 4  L_sXNadtVHjxMw7Yhvkj9Q         Naoki Ramen     915 Race St  Philadelphia
#
#   State  Postal_Code   Latitude  Longitude  Stars_Rating  Review_Count  ...  \
# 0    PA        19107  39.955505 -75.155564           4.0            80  ...
# 1    PA        19107  39.947033 -75.157434           4.5            72  ...
# 2    PA        19107  39.947207 -75.157252           4.0           217  ...
# 3    PA        19107  39.948751 -75.160449           2.5            63  ...
# 4    PA        19107  39.955454 -75.154900           4.0            92  ...
#
# ...

# %%
merged_df['Total_Estimate_Households_per_Zip'] = merged_df['Total_Estimate_Households_per_Zip'].astype('int64')
merged_df['Total_Estimate_Married-couple_Family_households'] = merged_df['Total_Estimate_Married-couple_Family_households'].astype('int64') 
merged_df['Total_Estimate_Nonfamily_households'] = merged_df['Total_Estimate_Nonfamily_households'].astype('int64')
merged_df['Median_Income(dollars)'] = merged_df['Median_Income(dollars)'].astype('int64')
merged_df['Mean_Income(dollars)'] = merged_df['Mean_Income(dollars)'].astype('int64')

# %%
merged_df.dtypes
# Out:
# Restaurant_ID                                       object
# Restaurants_Name                                    object
# Address                                             object
# City                                                object
# State                                               object
# Postal_Code                                          int64
# Latitude                                           float64
# Longitude                                          float64
# Stars_Rating                                       float64
# Review_Count                                         int64
# Restaurants_Delivery                                 int64
# Outdoor_Seating                                      int64
# Accepts_CreditCards                                  int64
# Price_Range                                          int64
# Alcohol                                              int64
# Good_For_Kids                                        int64
# ...

# %%
merged_df.head()
# Out:
#             Restaurant_ID    Restaurants_Name         Address          City  \
# 0  MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries     935 Race St  Philadelphia
# 1  WYYdQDjx-DsCanlP0DpImQ             J Sushi   243 S 10th St  Philadelphia
# 2  ngvE1G9IckUO-ljZBFo23w       Mumbai Bistro   930 Locust St  Philadelphia
# 3  IgNDlyLERBwFGphgcC5VDQ                Cosi  1128 Walnut St  Philadelphia
# 4  L_sXNadtVHjxMw7Yhvkj9Q         Naoki Ramen     915 Race St  Philadelphia
#
#   State  Postal_Code   Latitude  Longitude  Stars_Rating  Review_Count  ...  \
# 0    PA        19107  39.955505 -75.155564           4.0            80  ...
# 1    PA        19107  39.947033 -75.157434           4.5            72  ...
# 2    PA        19107  39.947207 -75.157252           4.0           217  ...
# 3    PA        19107  39.948751 -75.160449           2.5            63  ...
# 4    PA        19107  39.955454 -75.154900           4.0            92  ...
#
# ...

# %%
# population_df = pd.read_csv('CSV_files/Census_population_final.csv')

# %%
# population_df.head()

# %%
# population_df.info()

# %%
# New_merge_df = pd.merge(merged_df, population_df, left_on='Postal_Code', right_on='Postal_Code', how='left')

# %%
# New_merge_df.count()

# %%
# New_merge_df.dtypes

# %%
# New_merge_df.dropna(subset=['Population'], axis=0, inplace=True)

# %%
# New_merge_df['Population'] = New_merge_df['Population'].astype('int64')

# %%
# New_merge_df.count()

# %%
# New_merge_df.head()

# %%
# New_merge_df.dtypes

# %%
# New_merge_df.isnull().sum()

# %%
# New_merge_df.to_csv('CSV_files/new_merged_datasets.csv', index=False)

# %%
merged_df.to_csv('CSV_files/business_census_merged_dataset.csv', index=False)
