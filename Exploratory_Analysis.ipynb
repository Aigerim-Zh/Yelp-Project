# %%
import matplotlib.pyplot as plt
import pandas as pd

business_df = pd.read_csv("Clean_Business_Data.csv")

# Categorizing restaurants based on stars ratings
business_df["Category"] = pd.cut(business_df["Stars_Rating"],bins=[0.9,2,3,4,5],labels=["Poor","Average","Good","Successful"])

# %%
# There are no missing values
business_df.isnull().sum()
# Out:
# Unnamed: 0                    0
# Restaurant_ID                 0
# Restaurants_Name              0
# Address                     437
# City                          0
# State                         0
# Postal_Code                  19
# Latitude                      0
# Longitude                     0
# Stars_Rating                  0
# Review_Count                  0
# Restaurants_Delivery          0
# Outdoor_Seating               0
# Restaurants_TakeOut           0
# WiFi                          0
# Restaurants_Reservations      0
# Good_For_Groups               0
# Wheelchair_Accessible         0
# Happy_Hour                    0
# Dietary_Restrictions          0
# Category                      0
# dtype: int64

# %%
import seaborn as sns

sns.pairplot(data=business_df, diag_kind="kde")

# %%
labels=["Poor","Average","Good","Successful"]

# %%
plt.bar(business_df["Category"], business_df["Category"])
# Out:
# <BarContainer object of 49857 artists>

# %%
business_df["Category"].value_counts()
# Out:
# Good          24008
# Average       11847
# Successful     9533
# Poor           4469
# Name: Category, dtype: int64

# %%
X = business_df.drop(columns=['Unnamed: 0', 'Restaurant_ID', 'Restaurants_Name', 'Address', 'City',
       'State', 'Postal_Code', 'Latitude', 'Longitude', 'Stars_Rating', 'Category'])

# %%
business_df["Review_Count"].value_counts()
# Out:
# 5       1923
# 6       1588
# 7       1554
# 8       1323
# 9       1278
#         ...
# 1583       1
# 1019       1
# 823        1
# 980        1
# 998        1
# Name: Review_Count, Length: 1132, dtype: int64

# %%
business_df.columns
# Out:
# Index(['Unnamed: 0', 'Restaurant_ID', 'Restaurants_Name', 'Address', 'City',
#        'State', 'Postal_Code', 'Latitude', 'Longitude', 'Stars_Rating',
#        'Review_Count', 'Restaurants_Delivery', 'Outdoor_Seating',
#        'Restaurants_TakeOut', 'WiFi', 'Restaurants_Reservations',
#        'Good_For_Groups', 'Wheelchair_Accessible', 'Happy_Hour',
#        'Dietary_Restrictions', 'Category'],
#       dtype='object')

# %%
plt.scatter(business_df["Review_Count"], business_df["Stars_Rating"])

# %%
sns.boxplot(x=business_df["Restaurants_Delivery"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Restaurants_Delivery', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Outdoor_Seating"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Outdoor_Seating', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Restaurants_TakeOut"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Restaurants_TakeOut', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["WiFi"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='WiFi', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Restaurants_Reservations"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Restaurants_Reservations', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Good_For_Groups"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Good_For_Groups', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Wheelchair_Accessible"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Wheelchair_Accessible', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Happy_Hour"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Happy_Hour', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Dietary_Restrictions"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Dietary_Restrictions', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["State"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Stars_Rating'>
