# %%
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns
import numpy as np

business_df = pd.read_csv("Data/business_census_merged_dataset.csv")

# %%
# There are no missing values
business_df.isnull().sum()
# Out:
# Restaurant_ID                                       0
# Restaurants_Name                                    0
# Address                                            58
# City                                                0
# State                                               0
# Postal_Code                                         0
# Latitude                                            0
# Longitude                                           0
# Stars_Rating                                        0
# Review_Count                                        0
# Restaurants_Delivery                                0
# Outdoor_Seating                                     0
# Accepts_CreditCards                                 0
# Price_Range                                         0
# Alcohol                                             0
# Good_For_Kids                                       0
# Reservations                                        0
# ...

# %%
business_df["Stars_Rating"].value_counts()
# Most restaurants appear to be in the 4 star rating category
# Out:
# 4.0    7910
# 3.5    6111
# 4.5    4531
# 3.0    3196
# 2.5    1624
# 2.0     690
# 5.0     353
# 1.5     307
# 1.0      17
# Name: Stars_Rating, dtype: int64

# %%
business_df["Stars_Rating"].describe()
# Star Rating distribution is skewed to the right
# indicating outliers with extremely low star ratings
# Out:
# count    24739.000000
# mean         3.665811
# std          0.694513
# min          1.000000
# 25%          3.500000
# 50%          4.000000
# 75%          4.000000
# max          5.000000
# Name: Stars_Rating, dtype: float64

# %%
business_df.columns
# Out:
# Index(['Restaurant_ID', 'Restaurants_Name', 'Address', 'City', 'State',
#        'Postal_Code', 'Latitude', 'Longitude', 'Stars_Rating', 'Review_Count',
#        'Restaurants_Delivery', 'Outdoor_Seating', 'Accepts_CreditCards',
#        'Price_Range', 'Alcohol', 'Good_For_Kids', 'Reservations',
#        'Restaurants_TakeOut', 'WiFi', 'Good_For_Groups',
#        'Wheelchair_Accessible', 'Happy_Hour', 'Noise_Level',
#        'Dietary_Restrictions', 'Total_Estimate_Households_per_Zip',
#        'Total_Estimate_Married-couple_Family_households',
#        'Total_Estimate_Nonfamily_households', 'Median_Income(dollars)',
#        'Mean_Income(dollars)'],
#       dtype='object')

# %%
plt.scatter(business_df["Review_Count"], business_df["Stars_Rating"])

# %%
sns.barplot(x='Stars_Rating', y='Review_Count', data=business_df, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Stars_Rating', ylabel='Review_Count'>

# %%
sns.boxplot(x=business_df["Restaurants_Delivery"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Restaurants_Delivery', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Outdoor_Seating"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Outdoor_Seating', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Restaurants_TakeOut"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Restaurants_TakeOut', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["WiFi"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='WiFi', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Reservations"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Reservations', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Good_For_Groups"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Good_For_Groups', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Wheelchair_Accessible"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Wheelchair_Accessible', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Happy_Hour"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Happy_Hour', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Dietary_Restrictions"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Dietary_Restrictions', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["State"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='State', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Noise_Level"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Noise_Level', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Accepts_CreditCards"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Accepts_CreditCards', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Price_Range"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Price_Range', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Alcohol"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Stars_Rating'>

# %%
sns.boxplot(x=business_df["Good_For_Kids"], y=business_df["Stars_Rating"])
# Out:
# <AxesSubplot:xlabel='Good_For_Kids', ylabel='Stars_Rating'>

# %%
import numpy as np
sns.barplot(x='Stars_Rating', y='Median_Income(dollars)', data=business_df, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Stars_Rating', ylabel='Median_Income(dollars)'>

# %%
sns.barplot(x='Stars_Rating', y='Mean_Income(dollars)', data=business_df, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Stars_Rating', ylabel='Mean_Income(dollars)'>

# %%
sns.barplot(x='Stars_Rating', y='Total_Estimate_Households_per_Zip', data=business_df, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Stars_Rating', ylabel='Total_Estimate_Households_per_Zip'>

# %%
sns.barplot(x='Stars_Rating', y='Total_Estimate_Married-couple_Family_households', data=business_df, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Stars_Rating', ylabel='Total_Estimate_Married-couple_Family_households'>

# %%
sns.barplot(x='Stars_Rating', y='Total_Estimate_Nonfamily_households', data=business_df, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Stars_Rating', ylabel='Total_Estimate_Nonfamily_households'>
